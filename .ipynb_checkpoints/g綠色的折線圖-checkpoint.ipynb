# %%
pylab inline
# Out:
#   File "<ipython-input-17-b794e5809f34>", line 1
#     pylab inline
#                ^
# SyntaxError: invalid syntax

# %%
plot(randn(66),"g")

# %%
rate=(85,88,85,83,83,82)

# %%
pick=(1,2,3,4,5,6)

# %%
plot(pick,rate,"co")
