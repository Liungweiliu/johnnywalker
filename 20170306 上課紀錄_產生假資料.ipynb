# %%
# %matplotlib inline

# %%
import numpy as np #數學
import matplotlib.pyplot as plt #畫圖

# %%
x = np.linspace(0, 10, 100)

# %%
y = 66*x+6 + np.random.randint(-100, 100,100)

# %%
plt.scatter(x,y,color="#8DFFCD",lw=3)
plt.plot(x,y)

# %%
def f(x, a, b):
    return a*x + b

# %%
from scipy.optimize import curve_fit

# %%
popt, pcov = curve_fit(f, x, y) #p參數+opt最佳化 #p參數+cov

# %%
a, b = popt

# %%
plt.scatter(x,y,color="#8DFFCD",lw=3)
plt.plot(x, y)

# %%
a*12+b
# Out:
# 817.59374325724093

# %%
def g(x):
    return a*x + b

# %%
#分成訓練資料 測試資料

# %%
from sklearn.cross_validation import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state = 1)

# %%
len(x_train)
# Out:
# 80

# %%
plt.scatter(x_train, y_train)

# %%
popt, pcov = curve_fit(f, x_train, y_train)
a, b =popt

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, a*x_test + b, 'r')

# %%
MSE = np.sum(((a*x_test + b) - (y_test))**2/len(x_test))

# %%
MSE
# Out:
# 2871.1985968833419

# %%
#訓練誤差
popt, pcov = curve_fit(f, x_train, y_train)
a, b =popt
plt.scatter(x_train, y_train)
plt.plot(x_train, a*x_train + b, 'r')
MSE = np.sum(((a*x_train + b) - (y_train))**2/len(x_train))
MSE
# Out:
# 2954.6338096941554

# %%
#定義一下函數
x = np.linspace(0, 10, 100)
y = np.cos(x*2+1)-3*x**2+np.random.randint(-10,10,100)

# %%
#看一下
plt.scatter(x,y)

# %%
def h(x, a, b):
    return a*x + b

# %%
#隨機分割訓練數據以及測試數據
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state = 1)

# %%
#看一下x_train的大小
len(x_train)
# Out:
# 80

# %%
#最佳化
popt, pcov = curve_fit(h, x_train, y_train)
a, b =popt
#看一下
plt.scatter(x_train, y_train)
plt.plot(x_test, np.cos(x_test*2+1)-3*x_test**2+np.random.randint(-10,10,20), 'r')
#找差異
MSE1 = np.sum(((a*x_test + b) - (y_test))**2/len(x_test))
MSE1
# Out:
# 453.33903958409167

# %%
a
# Out:
# -29.737953698879409

# %%
b
# Out:
# 45.751637043050941

# %%
popt, pcov = curve_fit(h, x_train, y_train ,p0=[-29.737953698879409,45.751637043050941] )
a, b =popt
plt.scatter(x_train, y_train)
plt.plot(x_test, np.cos(x_test*2+1)-3*x_test**2+np.random.randint(-10,10,20), 'r')
#找差異
MSE2 = np.sum(((a*x_test + b) - (y_test))**2/len(x_test))
MSE2
# Out:
# 453.3390378889718
