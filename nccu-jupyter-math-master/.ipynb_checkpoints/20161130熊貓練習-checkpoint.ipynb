# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv")

# %%
df
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
df.loc[:, "country":"beer_servings"] #練習取行列
# Out:
#                   country  beer_servings
# 0             Afghanistan              0
# 1                 Albania             89
# 2                 Algeria             25
# 3                 Andorra            245
# 4                  Angola            217
# 5       Antigua & Barbuda            102
# 6               Argentina            193
# 7                 Armenia             21
# 8               Australia            261
# 9                 Austria            279
# 10             Azerbaijan             21
# 11                Bahamas            122
# 12                Bahrain             42
# 13             Bangladesh              0
# 14               Barbados            143
# 15                Belarus            142
# 16                Belgium            295
# 17                 Belize            263
# 18                  Benin             34
# 19                 Bhutan             23
# 20                Bolivia            167
# 21     Bosnia-Herzegovina             76
# ...

# %%
df_country = df.groupby("country").count()

# %%
df_continent = df.groupby("continent").count()

# %%
df_continent
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# continent
# Africa              53             53               53             53
# Asia                44             44               44             44
# Europe              45             45               45             45
# North America       23             23               23             23
# Oceania             16             16               16             16
# South America       12             12               12             12
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                   53
# Asia                                     44
# Europe                                   45
# North America                            23
# Oceania                                  16
# South America                            12

# %%
df_continent.plot(kind="Bar", subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000002D6720A7F0>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000002D6736C358>], dtype=object)

# %%
df_continent = df_continent.loc[:, "beer_servings":]

# %%
df_continent.plot(kind="Bar", subplots = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000002D676796D8>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000002D687EEB38>], dtype=object)
