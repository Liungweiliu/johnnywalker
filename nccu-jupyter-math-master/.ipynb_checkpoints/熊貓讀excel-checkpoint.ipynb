# %%
import pandas as pd

# %%
df_excel=pd.read_excel("開盤價分析.xlsx")
df_excel
# Out:
#            年月日    log開盤價   開盤價(元)
# 0   2016-01-18  3.885286  7678.67
# 1   2016-01-21  3.887233  7713.17
# 2   2016-01-22  3.888124  7729.01
# 3   2016-01-14  3.889419  7752.09
# 4   2016-01-13  3.892070  7799.56
# 5   2016-01-12  3.892536  7807.93
# 6   2016-01-15  3.892595  7809.00
# 7   2016-01-08  3.892718  7811.20
# 8   2016-01-25  3.892858  7813.73
# 9   2016-01-19  3.893010  7816.45
# 10  2016-01-28  3.893497  7825.22
# 11  2016-01-26  3.893878  7832.10
# 12  2016-01-20  3.894048  7835.17
# 13  2016-01-11  3.895190  7855.80
# 14  2016-01-27  3.895625  7863.66
# 15  2016-01-29  3.896569  7880.78
# 16  2016-01-07  3.901090  7963.24
# 17  2016-02-15  3.901821  7976.65
# 18  2016-05-16  3.904997  8035.21
# 19  2015-12-14  3.906263  8058.67
# 20  2016-01-06  3.906564  8064.25
# 21  2015-12-15  3.907115  8074.48
# 22  2016-05-17  3.907513  8081.89
# 23  2016-02-16  3.907997  8090.91
# 24  2016-05-13  3.908267  8095.93
# 25  2015-09-30  3.908332  8097.15
# ...

# %%
df_excel=pd.read_excel("第一次作業 開盤價分析.xlsx")
df_excel
# Out:
#            年月日   開盤價(元)   收盤價(元) Unnamed: 3       開盤價(元).1       收盤價(元).1
# 0   2016-01-18  7678.67  7811.18        平均值    8501.334199    8501.984892
# 1   2016-01-21  7713.17  7664.01        變異數  130533.630389  127825.402660
# 2   2016-01-22  7729.01  7756.18        NaN            NaN            NaN
# 3   2016-01-14  7752.09  7742.88        NaN            NaN            NaN
# 4   2016-01-13  7799.56  7824.61        NaN            NaN            NaN
# 5   2016-01-12  7807.93  7768.45        NaN            NaN            NaN
# 6   2016-01-15  7809.00  7762.01        NaN            NaN            NaN
# 7   2016-01-08  7811.20  7893.97        NaN            NaN            NaN
# 8   2016-01-25  7813.73  7894.15        NaN            NaN            NaN
# 9   2016-01-19  7816.45  7854.88        NaN            NaN            NaN
# 10  2016-01-28  7825.22  7905.10        NaN            NaN            NaN
# 11  2016-01-26  7832.10  7828.67        NaN            NaN            NaN
# ...

# %% [markdown]
# import pandas as pd
# # 讀excel
# df_excel=pd.read_excel("開盤價分析.xlsx")
# df_excel
#
# # 讀txt
