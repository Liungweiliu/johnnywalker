# %%
f = open("grades.csv", 'r', encoding="utf-8")

# %%
L = f.readlines() #讀入

# %%
f.close #切斷連結
# Out:
# <function TextIOWrapper.close>

# %%
L
# Out:
# ['姓名,國文,英文,數學,自然,社會\n',
#  '劉俊安,9,10,15,10,13\n',
#  '胡玉華,10,10,10,8,9\n',
#  '黃淑婷,13,15,8,11,14\n',
#  '陳上紫,10,10,8,9,14\n',
#  '崔靜成,13,12,14,12,13\n',
#  '張雅岳,13,12,12,12,8\n',
#  '梁俊翔,11,13,10,10,14\n',
#  '林金鳳,8,9,10,10,8\n',
#  '許協旺,9,9,12,10,10\n',
#  '郭雅惠,10,15,12,11,9\n',
#  '張志偉,14,9,8,10,12\n',
#  '周皇樺,13,9,13,14,15\n',
#  '李正偉,11,15,11,14,15\n',
#  '黃旭忠,15,14,9,12,10\n',
#  '葉雅琳,8,13,10,13,14\n',
#  '黃淑慧,11,8,10,12,15\n',
#  '吳芝菁,14,9,11,10,9\n',
#  '聶珮君,12,11,13,12,9\n',
#  '梁慧君,9,8,8,8,12\n',
#  '葉曉玲,14,9,11,15,9\n',
#  '陳智超,13,9,13,14,13\n',
#  '黃奕霞,9,8,11,13,8\n',
#  '沈昆純,12,14,10,9,9\n',
#  '許惠雯,10,13,12,14,10\n',
#  '陳竹伯,10,12,15,10,14\n',
#  '蔡亦瑄,13,13,14,13,12\n',
#  '戴喜寶,13,11,9,14,9\n',
#  '馮白屏,8,13,14,8,10\n',
#  '王金鳳,15,14,8,12,8\n',
#  '闕進綠,14,11,13,8,11\n',
#  '連瑋玲,8,10,14,8,13\n',
#  '林秀娟,15,12,9,9,15\n',
#  '林建亨,9,11,8,8,11\n',
#  '王佳蓉,14,15,9,9,8\n',
#  '曾淑玟,13,12,10,11,9\n',
#  '盧冠宏,14,11,10,11,11\n',
#  '詹威德,12,13,15,10,14\n',
#  '曾怡君,11,12,15,13,14\n',
# ...

# %%
student = L[80]

# %%
student
# Out:
# '宣宣士,9,10,12,15,13\n'

# %%
student.rsrtip('\n').split(',')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-20c213580c25> in <module>()
# ----> 1 student.rsrtip('\n').split(',')
#
# AttributeError: 'str' object has no attribute 'rsrtip'
