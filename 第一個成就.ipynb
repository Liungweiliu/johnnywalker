# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([2011,2012,2013,2014,2015],[22.7,19.6,21.2,23.7,22.4])

# %%
plot([2011,2012,2013,2014,2015],[22.7,19.6,21.2,23.7,22.4],"r*-",linewidth=3.0)
plt.axis([2010, 2016, 18, 25])
plt.title('Checkpoint1')
plt.xlabel('X axis')
plt.ylabel('Y axis')
