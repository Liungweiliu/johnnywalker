# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#引入數學、畫圖套件

# %%
from sklearn.datasets import load_iris
#裝入iris

# %%
iris = load_iris()
#讀入iris成為一個物件

# %%
x_01 = iris.data[:,(0,1)]   
x_02 = iris.data[:,(0,2)]
x_03 = iris.data[:,(0,3)]
x_12 = iris.data[:,(1,2)]
x_13 = iris.data[:,(1,3)]
x_23 = iris.data[:,(2,3)]
#每一列都抽

# %%
y = iris.target
#原本的分類

# %%
from sklearn.svm import SVC
#學習套件

# %%
clf = SVC()

# %%
clf.fit(x_01, y)###????
clf.fit(x_02, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
#plt.scatter(x_01[:, 0], x_01[:, 1], s=50, c=clf.predict(x_01))
#plt.scatter(x_02[:, 0], x_02[:, 1], s=50, c=clf.predict(x_02))
#plt.scatter(x_03[:, 0], x_03[:, 1], s=50, c=clf.predict(x_03))
plt.scatter(x_12[:, 0], x_12[:, 1], s=50, c=clf.predict(x_12))
#plt.scatter(x_13[:, 0], x_13[:, 1], s=50, c=clf.predict(x_13))
#plt.scatter(x_23[:, 0], x_23[:, 1], s=50, c=clf.predict(x_23))

# %%
import pandas as pd

# %%
type(x_01)
# Out:
# numpy.ndarray

# %%
type(iris)
# Out:
# sklearn.datasets.base.Bunch

# %%
type(load_iris())
# Out:
# sklearn.datasets.base.Bunch

# %%
df1 = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

# %%
df_1 = df1.loc[:,["sepal length (cm)"]]
df_2 = df1.loc[:,["sepal width (cm)"]]
df_3 = df1.loc[:,["petal length (cm)"]]
df_4 = df1.loc[:,["petal width (cm)"]]
df_t = df1.loc[:,["target"]]

# %%
df_12 = df1.loc[:,["sepal length (cm)","sepal width (cm)"]]
x12 = df_12.as_matrix(columns=None)

# %%
x1 = df_1.as_matrix(columns=None)
x2 = df_2.as_matrix(columns=None)
x3 = df_3.as_matrix(columns=None)
x4 = df_4.as_matrix(columns=None)
y = df_t.as_matrix(columns=None) #target
x1d2 = x1-x2 #sepal length (cm)減sepal width (cm)
x3d4 = x3-x4 #petal length (cm)減petal width (cm)

# %%
plt.scatter(x1d2, x3d4, s=50, c=y)##顏色分配尚未解決
#http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.as_matrix.html
#http://stackoverflow.com/questions/38105539/how-to-convert-a-scikit-learn-dataset-to-a-pandas-dataset

# %%
from sklearn.externals import joblib

# %%
clf1 = joblib.load("irislearn1.pkl")
clf2 = joblib.load("irislearn2.pkl")

# %%
plt.scatter(x_12[:, 0], x_12[:, 1], s=50, c=clf1.predict(x_12),cmap=plt.cm.Wistia)

# %%
plt.scatter(x_12[:, 0], x_12[:, 1], s=50, c=clf2.predict(x_12),cmap=plt.cm.Wistia)
