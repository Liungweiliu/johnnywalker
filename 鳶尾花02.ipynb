# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
from sklearn.svm import SVC

# %%
clf = SVC()

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])

# %%
df_1 = df1.loc[:,["sepal length (cm)"]]
df_2 = df1.loc[:,["sepal width (cm)"]]
df_3 = df1.loc[:,["petal length (cm)"]]
df_4 = df1.loc[:,["petal width (cm)"]]
df_t = df1.loc[:,["target"]]
df_12 = df1.loc[:,["sepal length (cm)","sepal width (cm)"]]
df_13 = df1.loc[:,["sepal length (cm)","petal length (cm)"]]
df_14 = df1.loc[:,["sepal length (cm)","petal width (cm)"]]
df_23 = df1.loc[:,["sepal length (cm)","petal length (cm)"]]
df_24 = df1.loc[:,["sepal length (cm)","petal width (cm)"]]
df_34 = df1.loc[:,["petal length (cm)","petal width (cm)"]]

# %%
x1 = df_1.as_matrix(columns=None)
x2 = df_2.as_matrix(columns=None)
x3 = df_3.as_matrix(columns=None)
x4 = df_4.as_matrix(columns=None)
y = df_t.as_matrix(columns=None) #target
x1d2 = x1-x2 #sepal length (cm)減sepal width (cm)
x3d4 = x3-x4 #petal length (cm)減petal width (cm)

# %%
df1=[] 
df2=[]
df1.append(x1d2)
df2.append(x3d4)

# %%
x1d2_3d4 = np.c_[x1d2,x3d4]

# %%
#len(x1d2)
len(x1d2_3d4)
# Out:
# 150

# %%
plt.scatter(x1d2, x3d4, s=50, c=y)

# %%
clf.fit(x1d2_3d4,y)
#plt.scatter(x1d2, x3d4, s=50, c=clf.predict(x1d2_3d4))
# Out:
# C:\Users\名\Anaconda3\lib\site-packages\sklearn\svm\base.py:514: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y_ = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
plt.scatter(x1d2, x3d4, s=50, c=clf.predict(x1d2_3d4))
